# %%
import pandas as pd
import glob
import config
from sqlalchemy import create_engine

ruta_directorio = "C:/Users/User/Downloads/OneDrive_icfes/REPORTES ICFES WEB/DEPARTAMENTOS/*.xls"
config.ruta
# Out:
# 'c:\\Users\\User\\Downloads\\fichas_icfes\\Tablas/'

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    # Leer las columnas A y B hasta la fila 100 de cada archivo
    df = pd.read_excel(archivo, sheet_name="Información general", usecols="A:B", nrows=20)
    df = df.dropna()
    df_transposed = df.T.reset_index(drop=True)
    df_transposed.columns = df_transposed.iloc[0]
    df_final = df_transposed.drop(df_transposed.index[0])

    # Renombrar las columnas según el diccionario
    nombres_columnas = {
        "Fecha de presentación del examen": "fecha_examen",
        "Fecha de corte del SIMAT": "corte_simat",
        "Fecha de actualización de datos ": "actualizacion_datos",
        "Entidad territorial": "entidad_territorial",
        "Tipo de entidad": "tipo_entidad",
        "Número de municipios adscritos": "municipios_adscritos",
        "Número de establecimientos": "establecimientos"
    }
    df_final.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df_final)

# Concatenar todos los DataFrames en uno solo
df_concatenado_0 = pd.concat(lista_dfs, ignore_index=True)

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_info_general.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_0.to_csv(ruta_csv, index=False)

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    # Leer las columnas A y B hasta la fila 100 de cada archivo
    df = pd.read_excel(archivo, sheet_name='Ficha técnica', skiprows=8)
    df = df.iloc[1:]
    fila_limite = df[df.iloc[:, 0].notna()].index[0] - 2
    df = df.iloc[:fila_limite]
    df_final = df.drop(columns=['Código DANE', 'Establecimientos educativos'])

    # Renombrar las columnas según el diccionario
    nombres_columnas = {
        'Paí/ET/Municipios': f'pai_et_municipios',
        'Matriculados': f'matriculados',
        'Registrados': f'registrados',
        'Presentes': f'presentes',
        'Publicados': f'publicados'
    }
    df_final.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df_final)

# Concatenar todos los DataFrames en uno solo
df_concatenado_1 = pd.concat(lista_dfs, ignore_index=True)

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_ficha_tecnica_a.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_1.to_csv(ruta_csv, index=False)
df_concatenado_1
# Out:
#                   pai_et_municipios  matriculados  registrados  presentes  \
# 0                          AMAZONAS           873          892        843
# 1     OFICIALES URBANOS DE AMAZONAS           611          601        576
# 2     OFICIALES RURALES DE AMAZONAS           222          249        225
# 3              PRIVADOS DE AMAZONAS            40           42         42
# 4                  GC 1 DE AMAZONAS            69          100         94
# ..                              ...           ...          ...        ...
# 657  OFICIALES RURALES DE ZIPAQUIRA           118          118        118
# 658           PRIVADOS DE ZIPAQUIRA           477          498        496
# 659               GC 2 DE ZIPAQUIRA           216          235        232
# 660               GC 3 DE ZIPAQUIRA          1104         1091       1083
# 661               GC 4 DE ZIPAQUIRA            49           50         50
#
#      publicados
# 0           843
# 1           576
# 2           225
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    # Leer el archivo con la condición específica
    df = pd.read_excel(archivo, sheet_name='Ficha técnica', skiprows=8)
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df[df.iloc[:, 0].notna()]
    
    # Renombrar las columnas según el diccionario
    nombres_columnas = {
        'Código DANE': f'codigo_dane',
        'Paí/ET/Municipios': f'pai_et_municipios',
        'Establecimientos educativos': f'establecimientos_educativos',
        'Matriculados': f'matriculados',
        'Registrados': f'registrados',
        'Presentes': f'presentes',
        'Publicados': f'publicados'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado2 = pd.concat(lista_dfs, ignore_index=True)

# Convertir todas las columnas numéricas a tipo de dato texto y eliminar la parte decimal
for col in df_concatenado2.select_dtypes(include=['float64']).columns:
    df_concatenado2[col] = df_concatenado2[col].astype(str).str.rstrip('.0')

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_ficha_tecnica_b.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado2.to_csv(ruta_csv, index=False)
df_concatenado2
# Out:
#         codigo_dane pai_et_municipios  \
# 0      391001000721           LETICIA
# 1      191001000012           LETICIA
# 2      291001000629           LETICIA
# 3      191001000501           LETICIA
# 4      191001000489           LETICIA
# ...             ...               ...
# 10041  325899001466         ZIPAQUIRÁ
# 10042  325899001601         ZIPAQUIRÁ
# 10043  325899001776         ZIPAQUIRÁ
# 10044  425899090447         ZIPAQUIRÁ
# 10045  325899001741         ZIPAQUIRÁ
#
#                              establecimientos_educativos  matriculados  \
# 0                      COLEGIO CRISTO REY MINUTO DE DIOS            29
# 1      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...           148
# 2                         I.E INDÍGENA MARÍA AUXILIADORA            32
# 3                       COL  NAVAL AF-41 ( ANTES JARDIN)             0
# 4         INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS            83
# ...                                                  ...           ...
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    # Leer las columnas A y B hasta la fila 100 de cada archivo
    df = pd.read_excel(archivo, sheet_name='Resultados generales', skiprows=8)
    df = df.iloc[1:]
    fila_limite = df[df.iloc[:, 0].notna()].index[0] - 2
    df = df.iloc[:fila_limite]
    df_final = df.drop(columns=['Código DANE', 'Establecimientos educativos'])

    # Renombrar las columnas según el diccionario
    nombres_columnas = {
        'Paí/ET/Municipios': f'pai_et_municipios',
        'Promedio Puntaje Global': f'prom_puntaje_global',
        'Comparación PG': f'comparacion_pg',
        'Desviación': f'desviacion',
        'Comparación DPG': f'comparacion_dpg'
    }
    df_final.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df_final)

# Concatenar todos los DataFrames en uno solo
df_concatenado_3 = pd.concat(lista_dfs, ignore_index=True)

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_resultados_generales_a.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_3.to_csv(ruta_csv, index=False)
df_concatenado_3
# Out:
#                   pai_et_municipios prom_puntaje_global comparacion_pg  \
# 0                          AMAZONAS                 225            NaN
# 1     OFICIALES URBANOS DE AMAZONAS                 231        Similar
# 2     OFICIALES RURALES DE AMAZONAS                 196          Mayor
# 3              PRIVADOS DE AMAZONAS                 290          Menor
# 4                  GC 1 DE AMAZONAS                 200          Mayor
# ..                              ...                 ...            ...
# 657  OFICIALES RURALES DE ZIPAQUIRA                 258        Similar
# 658           PRIVADOS DE ZIPAQUIRA                 303        Similar
# 659               GC 2 DE ZIPAQUIRA                 243          Mayor
# 660               GC 3 DE ZIPAQUIRA                 287        Similar
# 661               GC 4 DE ZIPAQUIRA                 328          Menor
#
#     desviacion comparacion_dpg
# 0           44             NaN
# 1           42         Similar
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    # Leer el archivo con la condición específica
    df = pd.read_excel(archivo, sheet_name='Resultados generales', skiprows=8)
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df[df.iloc[:, 0].notna()]
    
    # Renombrar las columnas según el diccionario
    nombres_columnas = {
        'Código DANE': f'codigo_dane',
        'Paí/ET/Municipios': f'pai_et_municipios',
        'Establecimientos educativos': f'establecimientos_educativos',
        'Promedio Puntaje Global': f'prom_puntaje_global',
        'Comparación PG': f'comparacion_pg',
        'Desviación': f'desviacion',
        'Comparación DPG': f'comparacion_dpg'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado4 = pd.concat(lista_dfs, ignore_index=True)

# Convertir todas las columnas numéricas a tipo de dato texto y eliminar la parte decimal
for col in df_concatenado4.select_dtypes(include=['float64']).columns:
    df_concatenado4[col] = df_concatenado4[col].astype(str).str.rstrip('.0')

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_resultados_generales_b.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado4.to_csv(ruta_csv, index=False)
df_concatenado4
# Out:
#         codigo_dane pai_et_municipios  \
# 0      391001000721           LETICIA
# 1      191001000012           LETICIA
# 2      291001000629           LETICIA
# 3      191001000501           LETICIA
# 4      191001000489           LETICIA
# ...             ...               ...
# 10041  325899001466         ZIPAQUIRÁ
# 10042  325899001601         ZIPAQUIRÁ
# 10043  325899001776         ZIPAQUIRÁ
# 10044  425899090447         ZIPAQUIRÁ
# 10045  325899001741         ZIPAQUIRÁ
#
#                              establecimientos_educativos prom_puntaje_global  \
# 0                      COLEGIO CRISTO REY MINUTO DE DIOS                 291
# 1      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...                 255
# 2                         I.E INDÍGENA MARÍA AUXILIADORA                 196
# 3                       COL  NAVAL AF-41 ( ANTES JARDIN)                 303
# 4         INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS                 221
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Lectura crítica', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df.iloc[1:]
    fila_limite = df[df.iloc[:, 0].notna()].index[0] - 2
    df = df.iloc[:fila_limite]
    df = df.drop(columns=['Código DANE_Unnamed: 0_level_1', 'Establecimientos educativos_Unnamed: 2_level_1'])
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PLC_Unnamed: 4_level_1': f'comparacion_plc',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DLC_Unnamed: 6_level_1': f'comparacion_dlc',
        'Porcentaje de estudiantes por niveles de desempeño_1': f'desempeno_1',
        'Porcentaje de estudiantes por niveles de desempeño_2': f'desempeno_2',
        'Porcentaje de estudiantes por niveles de desempeño_3': f'desempeno_3',
        'Porcentaje de estudiantes por niveles de desempeño_4': f'desempeno_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 1': f'aprendizaje_1',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 2': f'aprendizaje_2',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 3': f'aprendizaje_3'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_5 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_5['Competencia'] = 'Lectura Crítica'

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_lectura_critica_a.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_5.to_csv(ruta_csv, index=False)
df_concatenado_5
# Out:
#                   pai_et_municipios promedio comparacion_plc desviacion  \
# 0                          AMAZONAS       48             NaN          9
# 1     OFICIALES URBANOS DE AMAZONAS       50         Similar          9
# 2     OFICIALES RURALES DE AMAZONAS       43           Mayor          7
# 3              PRIVADOS DE AMAZONAS       61           Menor         10
# 4                  GC 1 DE AMAZONAS       43           Mayor          8
# ..                              ...      ...             ...        ...
# 657  OFICIALES RURALES DE ZIPAQUIRA       53           Mayor          9
# 658           PRIVADOS DE ZIPAQUIRA       62           Menor          8
# 659               GC 2 DE ZIPAQUIRA       51           Mayor          9
# 660               GC 3 DE ZIPAQUIRA       59         Similar          9
# 661               GC 4 DE ZIPAQUIRA       66           Menor          6
#
#     comparacion_dlc desempeno_1 desempeno_2 desempeno_3 desempeno_4  \
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Lectura crítica', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df[df.iloc[:, 0].notna()]
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Código DANE_Unnamed: 0_level_1': f'codigo_dane',
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Establecimientos educativos_Unnamed: 2_level_1': f'establecimientos_educativos',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PLC_Unnamed: 4_level_1': f'comparacion_plc',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DLC_Unnamed: 6_level_1': f'comparacion_dlc',
        'Porcentaje de estudiantes por niveles de desempeño_1': f'desempeno_1',
        'Porcentaje de estudiantes por niveles de desempeño_2': f'desempeno_2',
        'Porcentaje de estudiantes por niveles de desempeño_3': f'desempeno_3',
        'Porcentaje de estudiantes por niveles de desempeño_4': f'desempeno_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 1': f'aprendizaje_1',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 2': f'aprendizaje_2',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 3': f'aprendizaje_3'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_6 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_6['Competencia'] = 'Lectura Crítica'

# Convertir todas las columnas numéricas a tipo de dato texto y eliminar la parte decimal
for col in df_concatenado_6.select_dtypes(include=['float64']).columns:
    df_concatenado_6[col] = df_concatenado_6[col].astype(str).str.rstrip('.0')

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_lectura_critica_b.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_6.to_csv(ruta_csv, index=False)
df_concatenado_6
# Out:
#         codigo_dane pai_et_municipios  \
# 0      391001000721           LETICIA
# 1      191001000012           LETICIA
# 2      291001000629           LETICIA
# 3      191001000501           LETICIA
# 4      191001000489           LETICIA
# ...             ...               ...
# 10041  325899001466         ZIPAQUIRÁ
# 10042  325899001601         ZIPAQUIRÁ
# 10043  325899001776         ZIPAQUIRÁ
# 10044  425899090447         ZIPAQUIRÁ
# 10045  325899001741         ZIPAQUIRÁ
#
#                              establecimientos_educativos promedio  \
# 0                      COLEGIO CRISTO REY MINUTO DE DIOS       61
# 1      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...       54
# 2                         I.E INDÍGENA MARÍA AUXILIADORA       43
# 3                       COL  NAVAL AF-41 ( ANTES JARDIN)       61
# 4         INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS       48
# ...                                                  ...      ...
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Matemáticas', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df.iloc[1:]
    fila_limite = df[df.iloc[:, 0].notna()].index[0] - 2
    df = df.iloc[:fila_limite]
    df = df.drop(columns=['Código DANE_Unnamed: 0_level_1', 'Establecimientos educativos_Unnamed: 2_level_1'])
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PMAT_Unnamed: 4_level_1': f'comparacion_pmat',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DMAT_Unnamed: 6_level_1': f'comparacion_dmat',
        'Porcentaje de estudiantes por niveles de desempeño_1': f'desempeno_1',
        'Porcentaje de estudiantes por niveles de desempeño_2': f'desempeno_2',
        'Porcentaje de estudiantes por niveles de desempeño_3': f'desempeno_3',
        'Porcentaje de estudiantes por niveles de desempeño_4': f'desempeno_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 1': f'aprendizaje_1',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 2': f'aprendizaje_2',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 3': f'aprendizaje_3'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_7 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_7['Competencia'] = 'Matemáticas'

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_matematicas_a.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_7.to_csv(ruta_csv, index=False)
df_concatenado_7
# Out:
#                   pai_et_municipios promedio comparacion_pmat desviacion  \
# 0                          AMAZONAS       43              NaN         11
# 1     OFICIALES URBANOS DE AMAZONAS       45          Similar         10
# 2     OFICIALES RURALES DE AMAZONAS       36            Mayor          8
# 3              PRIVADOS DE AMAZONAS       59            Menor         10
# 4                  GC 1 DE AMAZONAS       37            Mayor          8
# ..                              ...      ...              ...        ...
# 657  OFICIALES RURALES DE ZIPAQUIRA       54            Mayor         10
# 658           PRIVADOS DE ZIPAQUIRA       62            Menor         11
# 659               GC 2 DE ZIPAQUIRA       50            Mayor          9
# 660               GC 3 DE ZIPAQUIRA       59          Similar         11
# 661               GC 4 DE ZIPAQUIRA       68            Menor          8
#
#     comparacion_dmat desempeno_1 desempeno_2 desempeno_3 desempeno_4  \
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Matemáticas', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df[df.iloc[:, 0].notna()]
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Código DANE_Unnamed: 0_level_1': f'codigo_dane',
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Establecimientos educativos_Unnamed: 2_level_1': f'establecimientos_educativos',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PMAT_Unnamed: 4_level_1': f'comparacion_pmat',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DMAT_Unnamed: 6_level_1': f'comparacion_dmat',
        'Porcentaje de estudiantes por niveles de desempeño_1': f'desempeno_1',
        'Porcentaje de estudiantes por niveles de desempeño_2': f'desempeno_2',
        'Porcentaje de estudiantes por niveles de desempeño_3': f'desempeno_3',
        'Porcentaje de estudiantes por niveles de desempeño_4': f'desempeno_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 1': f'aprendizaje_1',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 2': f'aprendizaje_2',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 3': f'aprendizaje_3'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_8 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_8['Competencia'] = 'Matemáticas'

# Convertir todas las columnas numéricas a tipo de dato texto y eliminar la parte decimal
for col in df_concatenado_8.select_dtypes(include=['float64']).columns:
    df_concatenado_8[col] = df_concatenado_8[col].astype(str).str.rstrip('.0')

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_matematicas_b.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_8.to_csv(ruta_csv, index=False)
df_concatenado_8
# Out:
#         codigo_dane pai_et_municipios  \
# 0      391001000721           LETICIA
# 1      191001000012           LETICIA
# 2      291001000629           LETICIA
# 3      191001000501           LETICIA
# 4      191001000489           LETICIA
# ...             ...               ...
# 10041  325899001466         ZIPAQUIRÁ
# 10042  325899001601         ZIPAQUIRÁ
# 10043  325899001776         ZIPAQUIRÁ
# 10044  425899090447         ZIPAQUIRÁ
# 10045  325899001741         ZIPAQUIRÁ
#
#                              establecimientos_educativos promedio  \
# 0                      COLEGIO CRISTO REY MINUTO DE DIOS       58
# 1      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...       50
# 2                         I.E INDÍGENA MARÍA AUXILIADORA       38
# 3                       COL  NAVAL AF-41 ( ANTES JARDIN)       62
# 4         INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS       41
# ...                                                  ...      ...
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Sociales y ciudadanas', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df.iloc[1:]
    fila_limite = df[df.iloc[:, 0].notna()].index[0] - 2
    df = df.iloc[:fila_limite]
    df = df.drop(columns=['Código DANE_Unnamed: 0_level_1', 'Establecimientos educativos_Unnamed: 2_level_1'])
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PSYC_Unnamed: 4_level_1': f'comparacion_psyc',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DSYC_Unnamed: 6_level_1': f'comparacion_dsyc',
        'Porcentaje de estudiantes por niveles de desempeño_1': f'desempeno_1',
        'Porcentaje de estudiantes por niveles de desempeño_2': f'desempeno_2',
        'Porcentaje de estudiantes por niveles de desempeño_3': f'desempeno_3',
        'Porcentaje de estudiantes por niveles de desempeño_4': f'desempeno_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 1': f'aprendizaje_1',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 2': f'aprendizaje_2',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 3': f'aprendizaje_3',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 4': f'aprendizaje_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 5': f'aprendizaje_5',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 6': f'aprendizaje_6'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_9 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_9['Competencia'] = 'Sociales y Ciudadanas'

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_sociales_ciudadanas_a.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_9.to_csv(ruta_csv, index=False)
df_concatenado_9
# Out:
#                   pai_et_municipios promedio comparacion_psyc desviacion  \
# 0                          AMAZONAS       43              NaN         10
# 1     OFICIALES URBANOS DE AMAZONAS       44          Similar         10
# 2     OFICIALES RURALES DE AMAZONAS       38            Mayor          7
# 3              PRIVADOS DE AMAZONAS       56            Menor         10
# 4                  GC 1 DE AMAZONAS       38            Mayor          7
# ..                              ...      ...              ...        ...
# 657  OFICIALES RURALES DE ZIPAQUIRA       48            Mayor         10
# 658           PRIVADOS DE ZIPAQUIRA       58            Menor         11
# 659               GC 2 DE ZIPAQUIRA       46            Mayor         10
# 660               GC 3 DE ZIPAQUIRA       55          Similar         11
# 661               GC 4 DE ZIPAQUIRA       62            Menor          7
#
#     comparacion_dsyc desempeno_1 desempeno_2 desempeno_3 desempeno_4  \
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Sociales y ciudadanas', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df[df.iloc[:, 0].notna()]
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Código DANE_Unnamed: 0_level_1': f'codigo_dane',
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Establecimientos educativos_Unnamed: 2_level_1': f'establecimientos_educativos',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PSYC_Unnamed: 4_level_1': f'comparacion_psyc',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DSYC_Unnamed: 6_level_1': f'comparacion_dsyc',
        'Porcentaje de estudiantes por niveles de desempeño_1': f'desempeno_1',
        'Porcentaje de estudiantes por niveles de desempeño_2': f'desempeno_2',
        'Porcentaje de estudiantes por niveles de desempeño_3': f'desempeno_3',
        'Porcentaje de estudiantes por niveles de desempeño_4': f'desempeno_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 1': f'aprendizaje_1',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 2': f'aprendizaje_2',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 3': f'aprendizaje_3',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 4': f'aprendizaje_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 5': f'aprendizaje_5',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 6': f'aprendizaje_6'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_10 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_10['Competencia'] = 'Sociales y Ciudadanas'

# Convertir todas las columnas numéricas a tipo de dato texto y eliminar la parte decimal
for col in df_concatenado_10.select_dtypes(include=['float64']).columns:
    df_concatenado_10[col] = df_concatenado_10[col].astype(str).str.rstrip('.0')

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_sociales_ciudadanas_b.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_10.to_csv(ruta_csv, index=False)
df_concatenado_10
# Out:
#         codigo_dane pai_et_municipios  \
# 0      391001000721           LETICIA
# 1      191001000012           LETICIA
# 2      291001000629           LETICIA
# 3      191001000501           LETICIA
# 4      191001000489           LETICIA
# ...             ...               ...
# 10041  325899001466         ZIPAQUIRÁ
# 10042  325899001601         ZIPAQUIRÁ
# 10043  325899001776         ZIPAQUIRÁ
# 10044  425899090447         ZIPAQUIRÁ
# 10045  325899001741         ZIPAQUIRÁ
#
#                              establecimientos_educativos promedio  \
# 0                      COLEGIO CRISTO REY MINUTO DE DIOS       56
# 1      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...       49
# 2                         I.E INDÍGENA MARÍA AUXILIADORA       37
# 3                       COL  NAVAL AF-41 ( ANTES JARDIN)       59
# 4         INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS       42
# ...                                                  ...      ...
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Ciencias naturales', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df.iloc[1:]
    fila_limite = df[df.iloc[:, 0].notna()].index[0] - 2
    df = df.iloc[:fila_limite]
    df = df.drop(columns=['Código DANE_Unnamed: 0_level_1', 'Establecimientos educativos_Unnamed: 2_level_1'])
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PCN_Unnamed: 4_level_1': f'comparacion_pcn',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DCN_Unnamed: 6_level_1': f'comparacion_dcn',
        'Porcentaje de estudiantes por niveles de desempeño_1': f'desempeno_1',
        'Porcentaje de estudiantes por niveles de desempeño_2': f'desempeno_2',
        'Porcentaje de estudiantes por niveles de desempeño_3': f'desempeno_3',
        'Porcentaje de estudiantes por niveles de desempeño_4': f'desempeno_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 1': f'aprendizaje_1',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 2': f'aprendizaje_2',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 3': f'aprendizaje_3',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 4': f'aprendizaje_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 5': f'aprendizaje_5',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 6': f'aprendizaje_6',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 7': f'aprendizaje_7',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 8': f'aprendizaje_8',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 9': f'aprendizaje_9',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 10': f'aprendizaje_10',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 11': f'aprendizaje_11',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 12': f'aprendizaje_12',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 13': f'aprendizaje_13',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 14': f'aprendizaje_14',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 15': f'aprendizaje_15',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 16': f'aprendizaje_16',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 17': f'aprendizaje_17',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 18': f'aprendizaje_18',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 19': f'aprendizaje_19',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 20': f'aprendizaje_20',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 21': f'aprendizaje_21',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 22': f'aprendizaje_22',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 23': f'aprendizaje_23',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 24': f'aprendizaje_24',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 25': f'aprendizaje_25',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 26': f'aprendizaje_26'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_11 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_11['Competencia'] = 'Ciencias Naturales'

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_ciencias_naturales_a.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_11.to_csv(ruta_csv, index=False)
df_concatenado_11
# Out:
#                   pai_et_municipios promedio comparacion_pcn desviacion  \
# 0                          AMAZONAS       45             NaN          9
# 1     OFICIALES URBANOS DE AMAZONAS       46         Similar          9
# 2     OFICIALES RURALES DE AMAZONAS       40           Mayor          7
# 3              PRIVADOS DE AMAZONAS       56           Menor          8
# 4                  GC 1 DE AMAZONAS       41           Mayor          7
# ..                              ...      ...             ...        ...
# 657  OFICIALES RURALES DE ZIPAQUIRA       51           Mayor          9
# 658           PRIVADOS DE ZIPAQUIRA       59           Menor          9
# 659               GC 2 DE ZIPAQUIRA       48           Mayor          8
# 660               GC 3 DE ZIPAQUIRA       57         Similar          9
# 661               GC 4 DE ZIPAQUIRA       63           Menor          7
#
#     comparacion_dcn desempeno_1 desempeno_2 desempeno_3 desempeno_4  \
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Ciencias naturales', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df[df.iloc[:, 0].notna()]
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Código DANE_Unnamed: 0_level_1': f'codigo_dane',
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Establecimientos educativos_Unnamed: 2_level_1': f'establecimientos_educativos',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PCN_Unnamed: 4_level_1': f'comparacion_pcn',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DCN_Unnamed: 6_level_1': f'comparacion_dcn',
        'Porcentaje de estudiantes por niveles de desempeño_1': f'desempeno_1',
        'Porcentaje de estudiantes por niveles de desempeño_2': f'desempeno_2',
        'Porcentaje de estudiantes por niveles de desempeño_3': f'desempeno_3',
        'Porcentaje de estudiantes por niveles de desempeño_4': f'desempeno_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 1': f'aprendizaje_1',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 2': f'aprendizaje_2',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 3': f'aprendizaje_3',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 4': f'aprendizaje_4',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 5': f'aprendizaje_5',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 6': f'aprendizaje_6',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 7': f'aprendizaje_7',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 8': f'aprendizaje_8',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 9': f'aprendizaje_9',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 10': f'aprendizaje_10',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 11': f'aprendizaje_11',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 12': f'aprendizaje_12',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 13': f'aprendizaje_13',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 14': f'aprendizaje_14',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 15': f'aprendizaje_15',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 16': f'aprendizaje_16',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 17': f'aprendizaje_17',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 18': f'aprendizaje_18',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 19': f'aprendizaje_19',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 20': f'aprendizaje_20',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 21': f'aprendizaje_21',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 22': f'aprendizaje_22',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 23': f'aprendizaje_23',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 24': f'aprendizaje_24',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 25': f'aprendizaje_25',
        'Porcentaje promedio de estudiantes que responde incorrectamente a los aprendizajes_Aprendizaje 26': f'aprendizaje_26'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_12 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_12['Competencia'] = 'Ciencias Naturales'

# Convertir todas las columnas numéricas a tipo de dato texto y eliminar la parte decimal
for col in df_concatenado_12.select_dtypes(include=['float64']).columns:
    df_concatenado_12[col] = df_concatenado_12[col].astype(str).str.rstrip('.0')

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_ciencias_naturales_b.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_12.to_csv(ruta_csv, index=False)
df_concatenado_12
# Out:
#         codigo_dane pai_et_municipios  \
# 0      391001000721           LETICIA
# 1      191001000012           LETICIA
# 2      291001000629           LETICIA
# 3      191001000501           LETICIA
# 4      191001000489           LETICIA
# ...             ...               ...
# 10041  325899001466         ZIPAQUIRÁ
# 10042  325899001601         ZIPAQUIRÁ
# 10043  325899001776         ZIPAQUIRÁ
# 10044  425899090447         ZIPAQUIRÁ
# 10045  325899001741         ZIPAQUIRÁ
#
#                              establecimientos_educativos promedio  \
# 0                      COLEGIO CRISTO REY MINUTO DE DIOS       56
# 1      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...       51
# 2                         I.E INDÍGENA MARÍA AUXILIADORA       38
# 3                       COL  NAVAL AF-41 ( ANTES JARDIN)       59
# 4         INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS       45
# ...                                                  ...      ...
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Inglés', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df.iloc[1:]
    fila_limite = df[df.iloc[:, 0].notna()].index[0] - 2
    df = df.iloc[:fila_limite]
    df = df.drop(columns=['Código DANE_Unnamed: 0_level_1', 'Establecimientos educativos_Unnamed: 2_level_1'])
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PING_Unnamed: 4_level_1': f'comparacion_ping',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DING_Unnamed: 6_level_1': f'comparacion_ding',
        'Porcentaje de estudiantes por niveles de desempeño_A-': f'desempeno_a_minus',
        'Porcentaje de estudiantes por niveles de desempeño_A1': f'desempeno_a1',
        'Porcentaje de estudiantes por niveles de desempeño_A2': f'desempeno_a2',
        'Porcentaje de estudiantes por niveles de desempeño_B1': f'desempeno_b1',
        'Porcentaje de estudiantes por niveles de desempeño_B+': f'desempeno_b_plus'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_13 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_13['Competencia'] = 'Inglés'

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_ingles_a.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_13.to_csv(ruta_csv, index=False)
df_concatenado_13
# Out:
#                   pai_et_municipios promedio comparacion_ping desviacion  \
# 0                          AMAZONAS       46              NaN         10
# 1     OFICIALES URBANOS DE AMAZONAS       46          Similar          9
# 2     OFICIALES RURALES DE AMAZONAS       41            Mayor          7
# 3              PRIVADOS DE AMAZONAS       61            Menor         12
# 4                  GC 1 DE AMAZONAS       41            Mayor          8
# ..                              ...      ...              ...        ...
# 657  OFICIALES RURALES DE ZIPAQUIRA       51            Mayor         10
# 658           PRIVADOS DE ZIPAQUIRA       65            Menor         12
# 659               GC 2 DE ZIPAQUIRA       48            Mayor          9
# 660               GC 3 DE ZIPAQUIRA       58          Similar         12
# 661               GC 4 DE ZIPAQUIRA       72            Menor          8
#
#     comparacion_ding desempeno_a_minus desempeno_a1 desempeno_a2 desempeno_b1  \
# ...

# %%
# Lista para almacenar cada DataFrame
lista_dfs = []

# Iterar sobre cada archivo en el directorio que coincide con el patrón
for archivo in glob.glob(ruta_directorio):
    df = pd.read_excel(archivo, sheet_name='Inglés', header=[8,9])
    # Aplanar el MultiIndex para simplificar el manejo de columnas
    df.columns = [f'{i}_{j}' if 'Unnamed' not in i else f'{j}' for i, j in df.columns]
    # Mantener solo las filas donde la primera columna tiene contenido no vacío
    df = df[df.iloc[:, 0].notna()]
    
    # Renombrar las columnas según las necesidades, ajustando según los nombres reales proporcionados
    nombres_columnas = {
        'Código DANE_Unnamed: 0_level_1': f'codigo_dane',
        'Paí/ET/Municipios_Unnamed: 1_level_1': f'pai_et_municipios',
        'Establecimientos educativos_Unnamed: 2_level_1': f'establecimientos_educativos',
        'Promedio_Unnamed: 3_level_1': f'promedio',
        'Comparación PING_Unnamed: 4_level_1': f'comparacion_ping',
        'Desviación_Unnamed: 5_level_1': f'desviacion',
        'Comparación DING_Unnamed: 6_level_1': f'comparacion_ding',
        'Porcentaje de estudiantes por niveles de desempeño_A-': f'desempeno_a_minus',
        'Porcentaje de estudiantes por niveles de desempeño_A1': f'desempeno_a1',
        'Porcentaje de estudiantes por niveles de desempeño_A2': f'desempeno_a2',
        'Porcentaje de estudiantes por niveles de desempeño_B1': f'desempeno_b1',
        'Porcentaje de estudiantes por niveles de desempeño_B+': f'desempeno_b_plus'
    }
    df.rename(columns=nombres_columnas, inplace=True)

    # Agregar el DataFrame a la lista
    lista_dfs.append(df)

# Concatenar todos los DataFrames en uno solo
df_concatenado_14 = pd.concat(lista_dfs, ignore_index=True)
df_concatenado_14['Competencia'] = 'Inglés'

# Convertir todas las columnas numéricas a tipo de dato texto y eliminar la parte decimal
for col in df_concatenado_14.select_dtypes(include=['float64']).columns:
    df_concatenado_14[col] = df_concatenado_14[col].astype(str).str.rstrip('.0')

# Ruta donde deseas guardar el archivo CSV
ruta_csv = f"{config.ruta}/dep_ingles_b.csv"

# Guardar el DataFrame como un archivo CSV
df_concatenado_14.to_csv(ruta_csv, index=False)
df_concatenado_14
# Out:
#         codigo_dane pai_et_municipios  \
# 0      391001000721           LETICIA
# 1      191001000012           LETICIA
# 2      291001000629           LETICIA
# 3      191001000501           LETICIA
# 4      191001000489           LETICIA
# ...             ...               ...
# 10041  325899001466         ZIPAQUIRÁ
# 10042  325899001601         ZIPAQUIRÁ
# 10043  325899001776         ZIPAQUIRÁ
# 10044  425899090447         ZIPAQUIRÁ
# 10045  325899001741         ZIPAQUIRÁ
#
#                              establecimientos_educativos promedio  \
# 0                      COLEGIO CRISTO REY MINUTO DE DIOS       62
# 1      I.E. ESCUELA NORMAL SUPERIOR MARCELIANO EDUARD...       52
# 2                         I.E INDÍGENA MARÍA AUXILIADORA       40
# 3                       COL  NAVAL AF-41 ( ANTES JARDIN)       64
# 4         INSTITUCION EDUCATIVA SAGRADO CORAZON DE JESUS       44
# ...                                                  ...      ...
# ...

# %%
import configparser

config = configparser.ConfigParser()
config.read(config.config_path)
server = config.get("database", "server")
user = config.get("database", "user")
password = config.get("database", "password")
database = config.get("database", "database")
db_driver = config.get("database", "driver")
connection_string = f"mssql+pyodbc://{user}:{password}@{server}/{database}?driver={db_driver}"

# %%
ruta_csv = f"{config.ruta}/dep_matematicas_b.csv"
df = pd.read_csv(ruta_csv)
engine = create_engine('mssql+pyodbc://localhost/MinEducacion?driver=ODBC+Driver+17+for+SQL+Server;Trusted_Connection=yes')
df.to_sql('matematicas', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:3282, in Engine.raw_connection(self)
#    3261 """Return a "raw" DBAPI connection from the connection pool.
#    3262
#    3263 The returned object is a proxied version of the DBAPI
#    (...)
#    3280
#    3281 """
# -> 3282 return self.pool.connect()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
# ...

# %%
import configparser
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

parametro = configparser.ConfigParser()
parametro.read(config.config_path)
server = parametro.get("database", "server")
database = parametro.get("database", "database")
db_driver = parametro.get("database", "driver")

connection_url = URL.create(
    "mssql+pyodbc",
    username="",
    password="",
    host=server,
    database=database,
    query={
        "driver": db_driver,
        "Trusted_Connection": "yes"
    },
)
engine = create_engine(connection_url)
# Out:
# 40

# %%
ruta_csv = f"{config.ruta}/dep_lectura_critica_b.csv"
df = pd.read_csv(ruta_csv)

df.to_sql('dep_lectura_critica', con=engine, if_exists='replace', index=False)
# Out:
# 40

# %%
ruta_csv = f"{config.ruta}/dep_matematicas_b.csv"
df = pd.read_csv(ruta_csv)

df.to_sql('dep_matematicas', con=engine, if_exists='replace', index=False)
# Out:
# 40

# %%
ruta_csv = f"{config.ruta}/dep_sociales_ciudadanas_b.csv"
df = pd.read_csv(ruta_csv)

df.to_sql('dep_sociales_ciudadanas', con=engine, if_exists='replace', index=False)
# Out:
# 72

# %%
ruta_csv = f"{config.ruta}/dep_ciencias_naturales_b.csv"
df = pd.read_csv(ruta_csv)

df.to_sql('dep_ciencias_naturales', con=engine, if_exists='replace', index=False)
# Out:
# 38

# %%
ruta_csv = f"{config.ruta}/dep_ingles_b.csv"
df = pd.read_csv(ruta_csv)

df.to_sql('dep_ingles', con=engine, if_exists='replace', index=False)
# Out:
# 66
